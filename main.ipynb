# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('dataset/student-por.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %%
df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
num_col = df.select_dtypes(include=['int64']).columns
df[num_col].hist(bins=15, figsize=(15, 10))
plt.suptitle('Histograms for Numerical Features')
plt.show()

# %%
cat_col = df.select_dtypes(include=['object']).columns
for columns in cat_col:
    plt.figure(figsize=(10, 6))
    sns.countplot(y=df[columns], order=df[columns].value_counts().index)
    plt.title(f'Frequency of {columns}')
    plt.show()

# %%
plt.figure(figsize=(15, 13))
num_features = df.select_dtypes(include=['int64', 'float64'])
correlation_matrix = num_features.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# ### Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['school'] = encoder.fit_transform(df['school'])
df['sex'] = encoder.fit_transform(df['sex'])
df['Mjob'] = encoder.fit_transform(df['Mjob'])
df['Fjob'] = encoder.fit_transform(df['Fjob'])
df['reason'] = encoder.fit_transform(df['reason'])
df['guardian'] = encoder.fit_transform(df['guardian'])
df['schoolsup'] = encoder.fit_transform(df['schoolsup'])
df['famsup'] = encoder.fit_transform(df['famsup'])
df['activities'] = encoder.fit_transform(df['activities'])
df['nursery'] = encoder.fit_transform(df['nursery'])
df['romantic'] = encoder.fit_transform(df['romantic'])
df['address'] = encoder.fit_transform(df['address'])
df['famsize'] = encoder.fit_transform(df['famsize'])
df['Pstatus'] = encoder.fit_transform(df['Pstatus'])
df['paid'] = encoder.fit_transform(df['paid'])
df['higher'] = encoder.fit_transform(df['higher'])
df['internet'] = encoder.fit_transform(df['internet'])

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    int64
#  1   sex         649 non-null    int64
#  2   age         649 non-null    int64
#  3   address     649 non-null    int64
#  4   famsize     649 non-null    int64
#  5   Pstatus     649 non-null    int64
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    int64
#  9   Fjob        649 non-null    int64
#  10  reason      649 non-null    int64
#  11  guardian    649 non-null    int64
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    int64
#  16  famsup      649 non-null    int64
#  17  paid        649 non-null    int64
#  18  activities  649 non-null    int64
# ...

# %%
df['age'].hist(bins=15, figsize=(10, 5))
plt.title('Age Distribution')

plt.figure(figsize=(12, 5))
sns.boxplot(x=df['age'], color='green')
plt.title('Age')
plt.show() #no outlier needed

# %%
df.head(15)
# Out:
#     school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0        0    0   18        1        0        0     4     4     0     4  ...
# 1        0    0   17        1        0        1     1     1     0     2  ...
# 2        0    0   15        1        1        1     1     1     0     2  ...
# 3        0    0   15        1        0        1     4     2     1     3  ...
# 4        0    0   16        1        0        1     3     3     2     2  ...
# 5        0    1   16        1        1        1     4     3     3     2  ...
# 6        0    1   16        1        1        1     2     2     2     2  ...
# 7        0    0   17        1        0        0     4     4     2     4  ...
# 8        0    1   15        1        1        0     3     2     3     2  ...
# 9        0    1   15        1        0        1     3     4     2     2  ...
# 10       0    0   15        1        0        1     4     4     4     1  ...
# ...

# %% [markdown]
# ### Split Dataset

# %%
from sklearn.model_selection import train_test_split

x = df.drop(columns='G3')
y = df['G3']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

model_linear_reg = LinearRegression()
model_linear_reg.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model_linear_reg.predict(x_test_scaled)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'MAE: {mae:.2f}')
print(f'MSE:{mse:.2f}')
print(f'RMSE: {rmse:.2f}')
print(f'R2: {r2:.2f}')
# Out:
# MAE: 0.78
# MSE:1.44
# RMSE: 1.20
# R2: 0.87

# %%
print('train')
# train
y_train_pred = model_linear_reg.predict(x_train)
mae_train = mean_absolute_error(y_train, y_train_pred)
r2_train = r2_score(y_train, y_train_pred)

# test
y_test_pred = model_linear_reg.predict(x_test)
mae_test = mean_absolute_error(y_test, y_test_pred)
r2_test = r2_score(y_test, y_test_pred)

print("Train MAE:", mae_train, "Train R2:", r2_train)
print("Test  MAE:", mae_test,  "Test  R2:", r2_test)
# Out:
# train
# d:\Documents\jean\sem 4\Machine Learning\machine_learning\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# Train MAE: 32.530311133865965 Train R2: -106.08598739272857
# Test  MAE: 33.23334376552965 Test  R2: -101.89623569193488
# d:\Documents\jean\sem 4\Machine Learning\machine_learning\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model_random_for = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

model_random_for.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = model_random_for.predict(x_test)

mae = mean_absolute_error(y_test, y_pred_rf)
rmse = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2 = r2_score(y_test, y_pred_rf)

print(f'MAE: {mae:.2f}')
print(f'RMSE: {rmse:.2f}')
print(f'R2: {r2:.2f}')
# Out:
# MAE: 0.95
# RMSE: 1.65
# R2: 0.75

# %% [markdown]
# ## Feature Importance

# %%
import pandas as pd

importance = pd.Series(
    model_random_for.feature_importances_,
    index=x_train.columns
).sort_values(ascending=False)

print(importance.head(10))
# Out:
# G2          0.165381
# G1          0.104315
# absences    0.047812
# age         0.045925
# freetime    0.040593
# goout       0.040182
# Fedu        0.036466
# health      0.035426
# Walc        0.034885
# Mjob        0.033126
# dtype: float64

# %% [markdown]
# ### Plotting

# %%
plt.Figure(figsize=(20, 8))

plt.subplot(1, 2, 1)
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel('Actual G3')
plt.ylabel('Predicted G3')
plt.title('Linear Regression')

plt.subplot(1, 2, 2)
plt.scatter(y_test, y_pred_rf)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel('Actual G3')
plt.ylabel('Predicted G3')
plt.title('Random Forest')

plt.legend()
plt.show()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_3908\1425191752.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(10, 8))
plt.scatter(y_test, y_pred, label='Linear Rregression')
plt.scatter(y_test, y_pred_rf, label='Random Forest')
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()])
plt.xlabel('Actual G3')
plt.ylabel('Predicted G3')
plt.legend()
plt.title('Model Comparison')
plt.show()

# %% [markdown]
# Random Forest exhibited lower performance compared to Linear Regression due to the predominantly linear relationship between previous grades (G1 and G2) and the final grade (G3). Given the relatively small dataset size and the strong linear signal, Random Forest tended to overfit and smooth predictions toward the mean, resulting in reduced accuracy, particularly for extreme values.
